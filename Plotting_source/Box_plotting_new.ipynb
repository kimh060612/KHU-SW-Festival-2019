# %%
import seaborn as sns
import csv
import pandas as pd
import matplotlib.pylab as plt

# %%
matrix = pd.read_csv('all.csv')

# %%
data = matrix.copy()

# %%
data
# Out:
#          Unnamed: 0  assists  boosts  damageDealt  DBNOs  headshotKills  \
# 0                 1        0       1       100.00      0              0
# 1                 2        0       0        17.81      0              0
# 2                 3        0       1       100.00      0              0
# 3                 4        0       0        36.00      0              0
# 4                 5        0       1       236.00      0              0
# ...             ...      ...     ...          ...    ...            ...
# 4411694     4411695        1       0       151.90      0              0
# 4411695     4411696        0       0       327.70      3              2
# 4411696     4411697        0       0         0.00      0              0
# 4411697     4411698        0       0        59.06      0              0
# 4411698     4411699        0       4       180.40      1              1
#
#          heals  killPlace  kills  killStreaks  ...  numGroups  revives  \
# ...

# %%
data['assistsCategories'] = pd.cut(data['assists'], [-1, 0, 1, 2, 4, 6, 12], 
                                   labels = ['0_assists','1_assists', '2_assists', '3-4_assists', '5-6_assists', '6+_assists'])
plt.figure(figsize=(15, 15))
sns.boxplot(x="assistsCategories", y="walkDistance", data=data)
plt.savefig("./Box_plotting_new/assistsCategories.png")

# %%
data['boostsCategories'] = pd.cut(data['boosts'], [-1, 2, 5, 8, 12, 15, 30], 
                                   labels = ['2_boosts','3-5_boosts', '6-8_boosts', '9-12_boosts', '13-15_boosts', '16+_boosts'])
plt.figure(figsize=(15,15))
sns.boxplot(x="boostsCategories", y="walkDistance", data=data)
plt.savefig("./Box_plotting_new/boostsCategories.png")

# %%
data['damageDealtCategories'] = pd.cut(data['damageDealt'], [-1, 100, 300, 500, 1000, 1500, 3500], 
                                   labels = ['0-100_damageDealt','101-300_damageDealt', '301-500_damageDealt', '501-1000_damageDealt', '1001-1500_damageDealt', '1500+_damageDealt'])
plt.figure(figsize=(15,15))
sns.boxplot(x="damageDealtCategories", y="walkDistance", data=data)
plt.savefig("./Box_plotting_new/damageDealtCategories.png")

# %%
data['DBNOsCategories'] = pd.cut(data['DBNOs'], [-1, 2, 5, 8, 12, 15, 30], 
                                   labels = ['0-2_DBNOs','3-5_DBNOs', '6-8_DBNOs', '9-12_DBNOs', '13-15_DBNOs', '16+_DBNOs'])
plt.figure(figsize=(15,15))
sns.boxplot(x="DBNOsCategories", y="walkDistance", data=data)
plt.savefig("./Box_plotting_new/DBNOsCategories.png")

# %%
data['headshotKillsCategories'] = pd.cut(data['headshotKills'], [-1, 0, 1, 4, 7, 10, 30], 
                                   labels = ['0_headshotKills','1_headshotKills', '2-4_headshotKills', '5-7_headshotKills', '6-10_headshotKills', '11+_headshotKills'])
plt.figure(figsize=(15,15))
sns.boxplot(x="headshotKillsCategories", y="walkDistance", data=data)
plt.savefig("./Box_plotting_new/headshotKillsCategories.png")

# %%
data['healsCategories'] = pd.cut(data['heals'], [-1, 5, 10, 15, 20, 25, 100], 
                                   labels = ['0-5_heals','6-10_heals', '11-15_heals', '16-20_heals', '21-25_heals', '26+_heals'])
plt.figure(figsize=(15,15))
sns.boxplot(x="healsCategories", y="walkDistance", data=data)
plt.savefig("./Box_plotting_new/healsCategories.png")

# %%
data['killPlaceCategories'] = pd.cut(data['killPlace'], [-1, 10, 20, 40, 60, 80, 100], 
                                   labels = ['0-10_killPlace','11-20_killPlace', '21-40_killPlace', '41-60_killPlace', '61-80_killPlace', '81+_killPlace'])
plt.figure(figsize=(15,15))
sns.boxplot(x="killPlaceCategories", y="walkDistance", data=data)
plt.savefig("./Box_plotting_new/killPlaceCategories.png")

# %%
data['killsCategories'] = pd.cut(data['kills'], [-1, 0, 2, 5, 9, 14, 30], 
                                   labels = ['0_kills','1-2_kills', '3-5_kills', '6-9_kills', '10-14_kills', '15+_kills'])
plt.figure(figsize=(15,15))
sns.boxplot(x="killsCategories", y="walkDistance", data=data)
plt.savefig("./Box_plotting_new/killsCategories.png")

# %%
data['killStreaksCategories'] = pd.cut(data['killStreaks'], [-1, 0, 1, 2, 3, 4, 30], 
                                   labels = ['0_killStreaks','1_killStreaks', '2_killStreaks', '3_killStreaks', '4_killStreaks', '5+_killStreaks'])
plt.figure(figsize=(15,15))
sns.boxplot(x="killStreaksCategories", y="walkDistance", data=data)
plt.savefig("./Box_plotting_new/killStreaksCategories.png")

# %%
data['longestKillCategories'] = pd.cut(data['longestKill'], [-1, 50, 100, 200, 300, 400, 2000], 
                                   labels = ['0-50_longestKill','51-100_longestKill', '101-200_longestKill', '201-300_longestKill', '201-400_longestKill', '401+_longestKill'])
plt.figure(figsize=(15,15))
sns.boxplot(x="longestKillCategories", y="walkDistance", data=data)
plt.savefig("./Box_plotting_new/longestKillCategories.png")

# %%
data['matchDurationCategories'] = pd.cut(data['matchDuration'], [-1, 1000, 1300, 1500, 1700, 2000, 5000], 
                                   labels = ['0-1000_matchDuration','1001-1300_matchDuration', '1301-1500_matchDuration', '1501-1700_matchDuration', '1701-2000_matchDuration', '2001+_matchDuration'])
plt.figure(figsize=(15,15))
sns.boxplot(x="matchDurationCategories", y="walkDistance", data=data)
plt.savefig("./Box_plotting_new/matchDurationCategories.png")
