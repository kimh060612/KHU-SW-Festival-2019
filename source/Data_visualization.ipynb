# %%
import Regression_class as RC

# %%
A = RC.REGRESSION("./train_duo_V2.csv")
A.preprocessing(A.table,A.labels)

# %%
A.Plotting_scatter("kills","damageDealt")

# %%
A.Plotting_scatter("killStreaks","killPlace")

# %%
A.Reg_Random_Forest("kills","damageDealt")
# Out:
# /home/michael/바탕화면/pubg-finish-placement-prediction/Regression_class.py:107: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   Regressor.fit(xTrain,yTrain)
# /home/michael/바탕화면/pubg-finish-placement-prediction/Regression_class.py:107: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   Regressor.fit(xTrain,yTrain)
# /home/michael/바탕화면/pubg-finish-placement-prediction/Regression_class.py:107: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   Regressor.fit(xTrain,yTrain)
# ...

# %%
A.Reg_Random_Forest("killPlace","winPlacePerc")
# Out:
# /home/michael/바탕화면/pubg-finish-placement-prediction/Regression_class.py:107: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   Regressor.fit(xTrain,yTrain)
# /home/michael/바탕화면/pubg-finish-placement-prediction/Regression_class.py:107: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   Regressor.fit(xTrain,yTrain)
# /home/michael/바탕화면/pubg-finish-placement-prediction/Regression_class.py:107: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   Regressor.fit(xTrain,yTrain)
# ...

# %%
A.Plotting_bar("killPlace","winPlacePerc")

# %%
A.Total_REG_CAT("Importance")
# Out:
# ...
# 0:	learn: 0.2792630	test: 0.2806171	best: 0.2806171 (0)	total: 64ms	remaining: 1m 3s
# 50:	learn: 0.0956683	test: 0.0959499	best: 0.0959499 (50)	total: 808ms	remaining: 15s
# 100:	learn: 0.0859758	test: 0.0862421	best: 0.0862421 (100)	total: 1.51s	remaining: 13.5s
# 150:	learn: 0.0811466	test: 0.0814112	best: 0.0814112 (150)	total: 2.21s	remaining: 12.4s
# 200:	learn: 0.0787299	test: 0.0790371	best: 0.0790371 (200)	total: 2.91s	remaining: 11.6s
# 250:	learn: 0.0771424	test: 0.0774866	best: 0.0774866 (250)	total: 3.61s	remaining: 10.8s
# 300:	learn: 0.0761548	test: 0.0765440	best: 0.0765440 (300)	total: 4.3s	remaining: 9.98s
# 350:	learn: 0.0755361	test: 0.0759621	best: 0.0759621 (350)	total: 4.98s	remaining: 9.21s
# 400:	learn: 0.0750339	test: 0.0755018	best: 0.0755018 (400)	total: 5.67s	remaining: 8.47s
# 450:	learn: 0.0747032	test: 0.0752128	best: 0.0752128 (450)	total: 6.35s	remaining: 7.73s
# ...

# %%
A.SHAP_Analysis("CAT",["kills","Distance"])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";funct
# ...

# %%
pred = A.PREDICTION("test_duo_V2","CAT")

# %%
pred
# Out:
# array([0.74933193, 0.08757513, 0.01392862, ..., 0.4974924 , 0.74743884,
#        0.77260688])

# %%
A.res_dict
# Out:
#         assists  boosts  damageDealt  DBNOs  headshotKills  heals  killPlace  \
# 0           1.0     0.0        68.00    0.0            0.0    0.0       47.0
# 1           0.0     6.0      1011.00    6.0            2.0    2.0        2.0
# 2           0.0     0.0         0.00    0.0            0.0    0.0       87.0
# 3           0.0     0.0        36.73    0.0            0.0    0.0       62.0
# 4           0.0     3.0         0.00    0.0            0.0    1.0       61.0
# ...         ...     ...          ...    ...            ...    ...        ...
# 313586      0.0     0.0        58.28    0.0            0.0    0.0       62.0
# 313587      0.0     1.0       306.70    0.0            1.0    2.0       26.0
# 313588      0.0     1.0         0.00    0.0            0.0    1.0       47.0
# 313589      1.0     3.0       736.50    4.0            1.0    2.0        7.0
# 313590      0.0     0.0         0.00    0.0            0.0    0.0       60.0
#
# ...

# %%
A.Total_REG_LG("Importance")
# Out:
# Training until validation scores don't improve for 100 rounds
# [10]	valid_0's rmse: 0.278186
# [20]	valid_0's rmse: 0.254863
# [30]	valid_0's rmse: 0.233906
# [40]	valid_0's rmse: 0.214919
# [50]	valid_0's rmse: 0.198169
# [60]	valid_0's rmse: 0.183116
# [70]	valid_0's rmse: 0.169613
# [80]	valid_0's rmse: 0.157721
# [90]	valid_0's rmse: 0.14706
# [100]	valid_0's rmse: 0.137763
# [110]	valid_0's rmse: 0.129876
# [120]	valid_0's rmse: 0.122587
# [130]	valid_0's rmse: 0.11611
# [140]	valid_0's rmse: 0.110491
# [150]	valid_0's rmse: 0.105753
# [160]	valid_0's rmse: 0.101479
# [170]	valid_0's rmse: 0.0977828
# [180]	valid_0's rmse: 0.0947212
# [190]	valid_0's rmse: 0.0920411
# [200]	valid_0's rmse: 0.0897093
# [210]	valid_0's rmse: 0.0875881
# [220]	valid_0's rmse: 0.0858067
# [230]	valid_0's rmse: 0.0841521
# [240]	valid_0's rmse: 0.0827906
# [250]	valid_0's rmse: 0.0816537
# [260]	valid_0's rmse: 0.0806542
# [270]	valid_0's rmse: 0.0797858
# [280]	valid_0's rmse: 0.0790594
# ...
