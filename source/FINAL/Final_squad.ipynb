# %%
import Regression_class as RC
import numpy as np
from sklearn.metrics import mean_squared_error

# %%
A = RC.REGRESSION("./train_squad_V2.csv")
A.preprocessing(A.table,A.labels)

# %%
A.Total_REG_LG("Importance")
# Out:
# Training until validation scores don't improve for 100 rounds
# [10]	valid_0's rmse: 0.289477
# [20]	valid_0's rmse: 0.266177
# [30]	valid_0's rmse: 0.245927
# [40]	valid_0's rmse: 0.227809
# [50]	valid_0's rmse: 0.211908
# [60]	valid_0's rmse: 0.197246
# [70]	valid_0's rmse: 0.18413
# [80]	valid_0's rmse: 0.172539
# [90]	valid_0's rmse: 0.162944
# [100]	valid_0's rmse: 0.154112
# [110]	valid_0's rmse: 0.146513
# [120]	valid_0's rmse: 0.140234
# [130]	valid_0's rmse: 0.13413
# [140]	valid_0's rmse: 0.128966
# [150]	valid_0's rmse: 0.124552
# [160]	valid_0's rmse: 0.120754
# [170]	valid_0's rmse: 0.117491
# [180]	valid_0's rmse: 0.114723
# [190]	valid_0's rmse: 0.112342
# [200]	valid_0's rmse: 0.110244
# [210]	valid_0's rmse: 0.108545
# [220]	valid_0's rmse: 0.106993
# [230]	valid_0's rmse: 0.105638
# [240]	valid_0's rmse: 0.104537
# [250]	valid_0's rmse: 0.103621
# [260]	valid_0's rmse: 0.102857
# [270]	valid_0's rmse: 0.102126
# [280]	valid_0's rmse: 0.101533
# ...

# %%
A.Total_REG_CAT("Importance")
# Out:
# ...
# 0:	learn: 0.2927404	test: 0.2926140	best: 0.2926140 (0)	total: 83.3ms	remaining: 1m 23s
# 50:	learn: 0.1164277	test: 0.1164292	best: 0.1164292 (50)	total: 1.7s	remaining: 31.5s
# 100:	learn: 0.1073957	test: 0.1074487	best: 0.1074487 (100)	total: 3.22s	remaining: 28.7s
# 150:	learn: 0.1030221	test: 0.1031058	best: 0.1031058 (150)	total: 4.77s	remaining: 26.8s
# 200:	learn: 0.1008816	test: 0.1010462	best: 0.1010462 (200)	total: 6.28s	remaining: 25s
# 250:	learn: 0.0998628	test: 0.1000752	best: 0.1000752 (250)	total: 7.77s	remaining: 23.2s
# 300:	learn: 0.0990804	test: 0.0993325	best: 0.0993325 (300)	total: 9.27s	remaining: 21.5s
# 350:	learn: 0.0986405	test: 0.0989274	best: 0.0989274 (350)	total: 10.8s	remaining: 19.9s
# 400:	learn: 0.0983069	test: 0.0986181	best: 0.0986181 (400)	total: 12.2s	remaining: 18.3s
# 450:	learn: 0.0980368	test: 0.0983749	best: 0.0983749 (450)	total: 13.7s	remaining: 16.7s
# ...

# %%
A.Total_REG_RF("Importance")

# %%
A.SHAP_Analysis("LG",["kills"])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";funct
# ...

# %%
A.SHAP_Analysis("CAT",["kills"])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";funct
# ...

# %%
pred_1 = A.PREDICTION("test_squad_V2", "LG")

# %%
pred = A.PREDICTION("test_squad_V2", "CAT")

# %%
Answer = np.ones(pred_1.shape)

# %%
Error = mean_squared_error(pred_1, Answer) #LG

# %%
Error_1 = mean_squared_error(pred, Answer) #CAT

# %%
Error
# Out:
# 0.39042020175673464

# %%
Error_1
# Out:
# 0.39031654707617797
