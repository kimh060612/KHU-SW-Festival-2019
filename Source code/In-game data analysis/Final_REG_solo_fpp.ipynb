# %%
import Regression_class as RC
import numpy as np
from sklearn.metrics import mean_squared_error

# %%
A = RC.REGRESSION("./train_solo_fpp_V2.csv")
A.preprocessing(A.table,A.labels)

# %%
A.Total_REG_LG("Importance")
# Out:
# Training until validation scores don't improve for 100 rounds
# [10]	valid_0's rmse: 0.268293
# [20]	valid_0's rmse: 0.244656
# [30]	valid_0's rmse: 0.223422
# [40]	valid_0's rmse: 0.204234
# [50]	valid_0's rmse: 0.187148
# [60]	valid_0's rmse: 0.171689
# [70]	valid_0's rmse: 0.157928
# [80]	valid_0's rmse: 0.145631
# [90]	valid_0's rmse: 0.134632
# [100]	valid_0's rmse: 0.124884
# [110]	valid_0's rmse: 0.116224
# [120]	valid_0's rmse: 0.108603
# [130]	valid_0's rmse: 0.101738
# [140]	valid_0's rmse: 0.0957185
# [150]	valid_0's rmse: 0.0905355
# [160]	valid_0's rmse: 0.0859548
# [170]	valid_0's rmse: 0.0819804
# [180]	valid_0's rmse: 0.0785471
# [190]	valid_0's rmse: 0.0756012
# [200]	valid_0's rmse: 0.073029
# [210]	valid_0's rmse: 0.0707796
# [220]	valid_0's rmse: 0.0688718
# [230]	valid_0's rmse: 0.0672392
# [240]	valid_0's rmse: 0.0658527
# [250]	valid_0's rmse: 0.0646208
# [260]	valid_0's rmse: 0.0636698
# [270]	valid_0's rmse: 0.062771
# [280]	valid_0's rmse: 0.0620172
# ...

# %%
A.Total_REG_CAT("Importance")
# Out:
# ...
# 0:	learn: 0.2708706	test: 0.2705026	best: 0.2705026 (0)	total: 74.3ms	remaining: 1m 14s
# 50:	learn: 0.0755755	test: 0.0756934	best: 0.0756934 (50)	total: 1.38s	remaining: 25.6s
# 100:	learn: 0.0679876	test: 0.0681762	best: 0.0681762 (100)	total: 2.63s	remaining: 23.4s
# 150:	learn: 0.0644740	test: 0.0646305	best: 0.0646305 (150)	total: 3.88s	remaining: 21.8s
# 200:	learn: 0.0621742	test: 0.0623137	best: 0.0623137 (200)	total: 5.13s	remaining: 20.4s
# 250:	learn: 0.0608700	test: 0.0610017	best: 0.0610017 (250)	total: 6.35s	remaining: 18.9s
# 300:	learn: 0.0599203	test: 0.0600512	best: 0.0600512 (300)	total: 7.58s	remaining: 17.6s
# 350:	learn: 0.0592438	test: 0.0593813	best: 0.0593813 (350)	total: 8.81s	remaining: 16.3s
# 400:	learn: 0.0587887	test: 0.0589292	best: 0.0589292 (400)	total: 10s	remaining: 15s
# 450:	learn: 0.0584220	test: 0.0585788	best: 0.0585788 (450)	total: 11.2s	remaining: 13.7s
# ...

# %%
A.Total_REG_RF("Importance")

# %%
A.SHAP_Analysis("LG",["kills"])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";funct
# ...

# %%
A.SHAP_Analysis("CAT",["kills"])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";funct
# ...

# %%
pred_1 = A.PREDICTION("test_solo_fpp_V2", "LG")

# %%
pred = A.PREDICTION("test_solo_fpp_V2", "CAT")

# %%
Answer = np.ones(pred_1.shape)

# %%
Error = mean_squared_error(pred_1, Answer) #LG

# %%
Error_1 = mean_squared_error(pred, Answer) #CAT

# %%
Error
# Out:
# 0.3431514315108104

# %%
Error_1
# Out:
# 0.34304298969011127
