# %%
import REGRESSION_CLASS_RE as RC
# Out:
# Using TensorFlow backend.
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.

# %%
A = RC.REGRESSION("home/michael/docker/data/train_duo_V2.csv")
A.preprocessing(A.table,A.labels)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-9d880706f17c> in <module>
# ----> 1 A = RC.REGRESSION("/data/train_duo_V2.csv")
#       2 A.preprocessing(A.table,A.labels)
#
# /data/PUBG_EDA/Source_code/In-game_data_analysis/Regression_class.py in __init__(self, file_path, encode)
#      27         self.path = file_path
#      28         self.res_dict = {}
# ---> 29         self.F = open(self.path, "r", encoding=encode)
#      30         self.rdr = csv.reader(self.F)
#      31         self.table = []
#
# FileNotFoundError: [Errno 2] No such file or directory: '/data/train_duo_V2.csv'

# %%
A.Total_REG_RF("Importance")
# Out:
# score:  0.07718040126633245

# %%
A.Total_REG_LG("Importance")
# Out:
# Training until validation scores don't improve for 100 rounds
# [10]	valid_0's rmse: 0.277838
# [20]	valid_0's rmse: 0.254327
# [30]	valid_0's rmse: 0.233603
# [40]	valid_0's rmse: 0.214985
# [50]	valid_0's rmse: 0.19861
# [60]	valid_0's rmse: 0.183526
# [70]	valid_0's rmse: 0.169908
# [80]	valid_0's rmse: 0.157819
# [90]	valid_0's rmse: 0.147624
# [100]	valid_0's rmse: 0.138231
# [110]	valid_0's rmse: 0.130075
# [120]	valid_0's rmse: 0.123164
# [130]	valid_0's rmse: 0.116526
# [140]	valid_0's rmse: 0.110873
# [150]	valid_0's rmse: 0.105934
# [160]	valid_0's rmse: 0.101632
# [170]	valid_0's rmse: 0.0978909
# [180]	valid_0's rmse: 0.0947076
# [190]	valid_0's rmse: 0.0920237
# [200]	valid_0's rmse: 0.0895146
# [210]	valid_0's rmse: 0.0875041
# [220]	valid_0's rmse: 0.0857417
# [230]	valid_0's rmse: 0.0841931
# [240]	valid_0's rmse: 0.0828892
# [250]	valid_0's rmse: 0.0817863
# [260]	valid_0's rmse: 0.0808599
# [270]	valid_0's rmse: 0.0799892
# [280]	valid_0's rmse: 0.0792239
# ...

# %%
A.SHAP_Analysis("LG",["kills"])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";funct
# ...

# %%
A.Total_REG_CAT("Importance")
# Out:
# ...
# 0:	learn: 0.2790682	test: 0.2804120	best: 0.2804120 (0)	total: 64.6ms	remaining: 1m 4s
# 50:	learn: 0.0944532	test: 0.0947441	best: 0.0947441 (50)	total: 783ms	remaining: 14.6s
# 100:	learn: 0.0851488	test: 0.0854034	best: 0.0854034 (100)	total: 1.68s	remaining: 15s
# 150:	learn: 0.0806925	test: 0.0809707	best: 0.0809707 (150)	total: 2.54s	remaining: 14.3s
# 200:	learn: 0.0781660	test: 0.0784782	best: 0.0784782 (200)	total: 3.2s	remaining: 12.7s
# 250:	learn: 0.0767348	test: 0.0770813	best: 0.0770813 (250)	total: 3.87s	remaining: 11.5s
# 300:	learn: 0.0759467	test: 0.0763262	best: 0.0763262 (300)	total: 4.52s	remaining: 10.5s
# 350:	learn: 0.0752964	test: 0.0757212	best: 0.0757212 (350)	total: 5.19s	remaining: 9.59s
# 400:	learn: 0.0749247	test: 0.0753886	best: 0.0753886 (400)	total: 5.83s	remaining: 8.71s
# 450:	learn: 0.0745978	test: 0.0751118	best: 0.0751118 (450)	total: 6.49s	remaining: 7.9s
# ...

# %%
A.SHAP_Analysis("CAT",["kills"])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";funct
# ...

# %%
pred = A.PREDICTION("test_duo_V2", "CAT")

# %%
pred
# Out:
# array([0.78214092, 0.08974327, 0.01771084, ..., 0.53190969, 0.74655212,
#        0.81238645])

# %%
pred_1 = A.PREDICTION("test_duo_V2","LG")

# %%
import numpy as np

# %%
Answer = np.ones(pred_1.shape)

# %%
from sklearn.metrics import mean_squared_error

# %%
Error = mean_squared_error(pred_1, Answer)

# %%
Error
# Out:
# 0.35521430049621877

# %%
Error_1 = mean_squared_error(pred, Answer)

# %%
Error_1
# Out:
# 0.35517426912978983
