# %%
import Regression_class as RC
import numpy as np
from sklearn.metrics import mean_squared_error

# %%
A = RC.REGRESSION("./train_solo_V2.csv")
A.preprocessing(A.table,A.labels)

# %%
A.Total_REG_RF("Importance")
# Out:
# score:  0.07706734342407237

# %%
A.Total_REG_LG("Importance")
# Out:
# Training until validation scores don't improve for 100 rounds
# [10]	valid_0's rmse: 0.280458
# [20]	valid_0's rmse: 0.256528
# [30]	valid_0's rmse: 0.235207
# [40]	valid_0's rmse: 0.215952
# [50]	valid_0's rmse: 0.19897
# [60]	valid_0's rmse: 0.183653
# [70]	valid_0's rmse: 0.170097
# [80]	valid_0's rmse: 0.158036
# [90]	valid_0's rmse: 0.147361
# [100]	valid_0's rmse: 0.137948
# [110]	valid_0's rmse: 0.129613
# [120]	valid_0's rmse: 0.122406
# [130]	valid_0's rmse: 0.115788
# [140]	valid_0's rmse: 0.110065
# [150]	valid_0's rmse: 0.105219
# [160]	valid_0's rmse: 0.100859
# [170]	valid_0's rmse: 0.0972109
# [180]	valid_0's rmse: 0.0940254
# [190]	valid_0's rmse: 0.0912572
# [200]	valid_0's rmse: 0.088812
# [210]	valid_0's rmse: 0.0866271
# [220]	valid_0's rmse: 0.0848875
# [230]	valid_0's rmse: 0.0832879
# [240]	valid_0's rmse: 0.0819531
# [250]	valid_0's rmse: 0.0808231
# [260]	valid_0's rmse: 0.0799403
# [270]	valid_0's rmse: 0.0790892
# [280]	valid_0's rmse: 0.0783421
# ...

# %%
A.Total_REG_CAT("Importance")
# Out:
# ...
# 0:	learn: 0.2841443	test: 0.2841183	best: 0.2841183 (0)	total: 55.5ms	remaining: 55.4s
# 50:	learn: 0.0979761	test: 0.0981577	best: 0.0981577 (50)	total: 428ms	remaining: 7.97s
# 100:	learn: 0.0884601	test: 0.0889157	best: 0.0889157 (100)	total: 776ms	remaining: 6.91s
# 150:	learn: 0.0828343	test: 0.0833440	best: 0.0833440 (150)	total: 1.13s	remaining: 6.37s
# 200:	learn: 0.0799249	test: 0.0805302	best: 0.0805302 (200)	total: 1.48s	remaining: 5.87s
# 250:	learn: 0.0780640	test: 0.0787518	best: 0.0787518 (250)	total: 1.82s	remaining: 5.43s
# 300:	learn: 0.0766431	test: 0.0773793	best: 0.0773793 (300)	total: 2.17s	remaining: 5.03s
# 350:	learn: 0.0757101	test: 0.0765312	best: 0.0765312 (350)	total: 2.51s	remaining: 4.64s
# 400:	learn: 0.0750280	test: 0.0758714	best: 0.0758713 (399)	total: 2.85s	remaining: 4.26s
# 450:	learn: 0.0744161	test: 0.0753150	best: 0.0753150 (450)	total: 3.2s	remaining: 3.89s
# ...

# %%
A.SHAP_Analysis("LG",["kills"])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";funct
# ...

# %%
A.SHAP_Analysis("CAT",["kills"])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";funct
# ...

# %%
PRED = A.PREDICTION("test_duo_V2")

# %%
pred_1 = A.PREDICTION("test_solo_V2", "LG")

# %%
pred = A.PREDICTION("test_solo_V2", "CAT")

# %%
Answer = np.ones(pred_1.shape)

# %%
Error = mean_squared_error(pred_1, Answer) #LG

# %%
Error_1 = mean_squared_error(pred, Answer) #CAT

# %%
Error
# Out:
# 0.3513580786544452

# %%
Error_1
# Out:
# 0.3511243151326339
