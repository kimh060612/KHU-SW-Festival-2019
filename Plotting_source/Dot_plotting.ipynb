# %%
import seaborn as sns
import csv
import pandas as pd
import matplotlib.pylab as plt

# %%
matrix = pd.read_csv('all.csv')

# %%
col = [ 'assists', 'boosts', 'damageDealt', 'DBNOs',
       'headshotKills', 'heals', 'killPlace', 'kills', 'killStreaks',
       'longestKill', 'matchDuration', 'numGroups', 'revives', 'rideDistance',
       'roadKills', 'swimDistance', 'teamKills', 'vehicleDestroys',
       'walkDistance', 'weaponsAcquired', 'winPlacePerc']

# %%
for name in col:
    fname = "./BoxPlotting/walkDistance_"+name+".png"
    sns.jointplot(x=name, y="walkDistance", data=matrix, alpha=0.003)
    plt.savefig(fname)
# Out:
# /home/subinpark/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:1675: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   f = plt.figure(figsize=(height, height))

# %%
for name in col:
    fname = "./BoxPlotting/killPlace_"+name+".png"
    sns.jointplot(x=name, y="killPlace", data=matrix, alpha=0.003)
    plt.savefig(fname)

# %%
fname = "./BoxPlotting/DBNOs_heals.png"
sns.jointplot(x="heals", y="DBNOs", data=matrix, alpha=0.003)
plt.savefig(fname)

# %%
fname = "./BoxPlotting/DBNOs_revives.png"
sns.jointplot(x="revives", y="DBNOs", data=matrix, alpha=0.003)
plt.savefig(fname)

# %%
fname = "./BoxPlotting/roadKills_rideDistance.png"
sns.jointplot(x="rideDistance", y="roadKills", data=matrix, alpha=0.003)
plt.savefig(fname)

# %%
sns.scatterplot(x="rideDistance", y="roadKills", data=matrix)
