# %%
import Regression_class as RC

# %%
A = RC.REGRESSION("./V4_data/train_duo_V4.csv")
A.preprocessing(A.table,A.labels)

# %%
A.Total_REG_RF("Importance")
# Out:
# 50th ensemble tree complete!
# 60th ensemble tree complete!
# 70th ensemble tree complete!
# 80th ensemble tree complete!
# 90th ensemble tree complete!
# 100th ensemble tree complete!
# 110th ensemble tree complete!
# 120th ensemble tree complete!
# 130th ensemble tree complete!
# 140th ensemble tree complete!
# score:  0.0894902271556289

# %%
A.Total_REG_LG("Importance")
# Out:
# Training until validation scores don't improve for 100 rounds
# [10]	valid_0's rmse: 0.279213
# [20]	valid_0's rmse: 0.256849
# [30]	valid_0's rmse: 0.23687
# [40]	valid_0's rmse: 0.218627
# [50]	valid_0's rmse: 0.202623
# [60]	valid_0's rmse: 0.188428
# [70]	valid_0's rmse: 0.175546
# [80]	valid_0's rmse: 0.164494
# [90]	valid_0's rmse: 0.154403
# [100]	valid_0's rmse: 0.145686
# [110]	valid_0's rmse: 0.138489
# [120]	valid_0's rmse: 0.131703
# [130]	valid_0's rmse: 0.125724
# [140]	valid_0's rmse: 0.120496
# [150]	valid_0's rmse: 0.116262
# [160]	valid_0's rmse: 0.112467
# [170]	valid_0's rmse: 0.109008
# [180]	valid_0's rmse: 0.106384
# [190]	valid_0's rmse: 0.103998
# [200]	valid_0's rmse: 0.101957
# [210]	valid_0's rmse: 0.100068
# [220]	valid_0's rmse: 0.0984087
# [230]	valid_0's rmse: 0.0968793
# [240]	valid_0's rmse: 0.0955596
# [250]	valid_0's rmse: 0.0945306
# [260]	valid_0's rmse: 0.0935337
# [270]	valid_0's rmse: 0.0927261
# [280]	valid_0's rmse: 0.0920155
# ...

# %%
A.index_labels
# Out:
# ['assists',
#  'boosts',
#  'damageDealt',
#  'DBNOs',
#  'headshotKills',
#  'heals',
#  'killPlace',
#  'killPoints',
#  'kills',
#  'killStreaks',
#  'longestKill',
#  'matchDuration',
#  'numGroups',
#  'rankPoints',
#  'revives',
#  'roadKills',
#  'teamKills',
#  'vehicleDestroys',
#  'weaponsAcquired',
#  'winPoints',
#  'Distance']

# %%
A.SHAP_Analysis("LG",["kills"])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";funct
# ...

# %%
A.Total_REG_CAT("Importance")
# Out:
# ...
# 0:	learn: 0.2817117	test: 0.2827763	best: 0.2827763 (0)	total: 66.1ms	remaining: 1m 6s
# 50:	learn: 0.1082955	test: 0.1090973	best: 0.1090973 (50)	total: 957ms	remaining: 17.8s
# 100:	learn: 0.0970031	test: 0.0977893	best: 0.0977893 (100)	total: 1.81s	remaining: 16.1s
# 150:	learn: 0.0922290	test: 0.0929860	best: 0.0929860 (150)	total: 2.65s	remaining: 14.9s
# 200:	learn: 0.0899704	test: 0.0906988	best: 0.0906988 (200)	total: 3.48s	remaining: 13.9s
# 250:	learn: 0.0888430	test: 0.0896140	best: 0.0896140 (250)	total: 4.3s	remaining: 12.8s
# 300:	learn: 0.0879045	test: 0.0886850	best: 0.0886850 (300)	total: 5.14s	remaining: 11.9s
# 350:	learn: 0.0872992	test: 0.0880985	best: 0.0880985 (350)	total: 5.96s	remaining: 11s
# 400:	learn: 0.0868720	test: 0.0876932	best: 0.0876932 (400)	total: 6.77s	remaining: 10.1s
# 450:	learn: 0.0865273	test: 0.0873796	best: 0.0873796 (450)	total: 7.59s	remaining: 9.24s
# ...

# %%
A.SHAP_Analysis("CAT",["kills"])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";funct
# ...

# %%
A.Total_REG_RF("Importance")
# Out:
# 50th ensemble tree complete! Error:  0.008023999464812899
# 60th ensemble tree complete! Error:  0.007999451719756055
# 70th ensemble tree complete! Error:  0.00797878831799352
# 80th ensemble tree complete! Error:  0.007962885787832826
# 90th ensemble tree complete! Error:  0.007946511064953803
# score:  0.08970376277578529

# %%
A.SHAP_Analysis("RF",["kills"])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";funct
# ...
